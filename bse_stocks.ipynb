# %%
import requests
from io import BytesIO, StringIO
import pandas as pd

# %%
def fetch_stocks():
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0 Safari/537.36"
    }
    resp = requests.get(
        "https://www.bseindia.com/downloads1/List_of_companies.csv",
        headers=headers,
        timeout=15,
    )
    resp.raise_for_status()
    content = resp.content

    # Try decode as UTF-8 text first, otherwise read as bytes
    try:
        text = content.decode("utf-8")
        df = pd.read_csv(StringIO(text))
    except Exception:
        df = pd.read_csv(BytesIO(content))

    return df

# %%
fetch_stocks()
# Out:
#     List of GSM companies w.e.f 06.06.2019  Unnamed: 1  \
# 0                                  Sr. No.  Scrip code
# 1                                        1      540874
# 2                                        2      538351
# 3                                        3      531611
# 4                                        4      542377
# ..                                     ...         ...
# 844                                    844      531663
# 845                                    845      531845
# 846                                    846      508900
# 847                                    847      531404
# 848                                    848      532883
#
#                                  Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0                             Security Name          ISIN  GSM Stage
# 1                   7Seas Entertainment Ltd  INE454F01010          I
# 2                      A.F. Enterprises Ltd  INE663P01015         II
# 3                Aadhaar Ventures India Ltd  INE063D01030         VI
# 4    Aar Shyam India Investment Company Ltd  INE512R01010          I
# ..                                      ...           ...        ...
# 844            Yuvraaj Hygiene Products Ltd  INE139D01020         II
# 845                Zenith Birla (India) Ltd  INE318D01020          I
# 846                     Zenith Capitals Ltd  INE132N01016        III
# 847   Zicom Electronic Security Systems Ltd  INE871B01014          I
# 848                       Zylog Systems Ltd  INE225I01026          I
#
# [849 rows x 5 columns]
